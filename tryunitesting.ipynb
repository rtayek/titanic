# %%
import numpy as np
import pandas as pd

path="data/"
train = pd.read_csv(path+"train.csv")
train.head() # does not print in jupyter notebook.
print("looks like our training data has shape: "+str(train.shape))
print("training data: "+str(train.head(3)))
#print('training info:')
#print("training info: "+str(train.info()))
#train.info() # this prints without the nonsense.
print("-------------------------------------------")
columns=train.columns.values
print("columns: "+str(columns))
for column in columns:
    x=train[column]
    are_any_null=x.isnull().any()
    if x.isnull().any():
        print("column "+str(column)+" has nulls!")
    else:
        print("column "+str(column)+" has no nulls.")
        if np.issubdtype(x, np.number):
            print("\tthis is a numeric data type: "+str(x.dtype))
            print(str(x.describe()))

        
test=pd.read_csv(path+"test.csv")
print("test data shape: "+str(test.shape))
print("test data: "+str(test.head()))

all = train.append( test , ignore_index = True )
all.head()

titanic = all[ :891 ]
# Out:
# looks like our training data has shape: (891, 12)
# training data:    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# -------------------------------------------
# columns: ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']
# column PassengerId has no nulls.
# 	this is a numeric data type: int64
# count    891.000000
# ...

# %%
import unittest

class TestStringMethods(unittest.TestCase):
    def test_for_training_data_present(self):
        self.assertFalse(train is None)
    def test_for_test_data_present(self):
        self.assertFalse(test is None)
    def test_shape_of_training_data(self):
        self.assertTrue(train.shape==(891, 12))
    def test_shape_of_test_data(self):
        self.assertTrue(test.shape==(418, 11))
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
    #unittest.main()
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.011s
#
# OK
